# %% [markdown]
# ## Exercise: Unlucky Numbers
#
# A clear method, assigning reply to a variable
# then compiling a print statement at the end...
# the conditionals are shorter/cleaner this way

# %%
max = 20

for n in range(1, max+1):
    if n==4 or n==13:
        state = 'UNLUCKY!!!'
    elif n % 2 != 0:
        state = 'odd'
    # could just be else, but this is more clear
    elif n % 2 == 0:
        state = 'even'
    print('{} is {}'.format(n, state))
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is UNLUCKY!!!
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
# 11 is odd
# 12 is even
# 13 is UNLUCKY!!!
# 14 is even
# 15 is odd
# 16 is even
# 17 is odd
# 18 is even
# 19 is odd
# 20 is even

# %% [markdown]
# ## Exercise: While Loops

# %%
from random import randint

number = 0
i = 0
while number != 5:
    i += 1
    number = randint(1, 10)

print("Got to 5 on try #{}".format(i))

# %% [markdown]
# ## Exercise: While Emojis

# %% [markdown]
# For loop version…

# %%
for x in range(3):
  for e in range(1, 11):
    print("\U0001f600" * e)
# Out:
# 😀
# 😀😀
# 😀😀😀
# 😀😀😀😀
# 😀😀😀😀😀
# 😀😀😀😀😀😀
# 😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀😀
# 😀
# 😀😀
# 😀😀😀
# 😀😀😀😀
# 😀😀😀😀😀
# 😀😀😀😀😀😀
# 😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀😀
# 😀
# 😀😀
# 😀😀😀
# 😀😀😀😀
# 😀😀😀😀😀
# 😀😀😀😀😀😀
# 😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀😀

# %% [markdown]
# While loop version…

# %%
e = 1
while e <= 10:
  print("\U0001f600" * e)
  e += 1
# Out:
# 😀
# 😀😀
# 😀😀😀
# 😀😀😀😀
# 😀😀😀😀😀
# 😀😀😀😀😀😀
# 😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀😀

# %% [markdown]
# Unnecessary complex version…
#
# without `* e` repeater

# %%
for num in range(1, 11):
  count = 1
  smileys = ""
  while count <= num:
    smileys += "\U0001f600"
    count += 1
  print(smileys)
# Out:
# 😀
# 😀😀
# 😀😀😀
# 😀😀😀😀
# 😀😀😀😀😀
# 😀😀😀😀😀😀
# 😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀
# 😀😀😀😀😀😀😀😀😀😀

# %% [markdown]
# ## Exercise: ASCII Art
#
# Using **pyfiglet** and **termcolor** to create giant colored text.

# %%
from pyfiglet import figlet_format
from termcolor import colored

def run_fig( msg, color="white" ):

    valid_colors = ("red", "green", "yellow", "blue",
                    "magenta", "cyan", "white")
    if color not in valid_colors:
        color = "white"
    print(colored(figlet_format(msg), color=color))


run_fig( "Hi from PyFiglet!", "cyan" )
run_fig( "There are none", "blue" )
run_fig( "FIGLETS" )
# Out:
#  _   _ _    __                       ____        _____ _       _      _   _
# | | | (_)  / _|_ __ ___  _ __ ___   |  _ \ _   _|  ___(_) __ _| | ___| |_| |
# | |_| | | | |_| '__/ _ \| '_ ` _ \  | |_) | | | | |_  | |/ _` | |/ _ \ __| |
# |  _  | | |  _| | | (_) | | | | | | |  __/| |_| |  _| | | (_| | |  __/ |_|_|
# |_| |_|_| |_| |_|  \___/|_| |_| |_| |_|    \__, |_|   |_|\__, |_|\___|\__(_)
#                                            |___/         |___/
#
#  _____ _
# |_   _| |__   ___ _ __ ___    __ _ _ __ ___   _ __   ___  _ __   ___
#   | | | '_ \ / _ \ '__/ _ \  / _` | '__/ _ \ | '_ \ / _ \| '_ \ / _ \
#   | | | | | |  __/ | |  __/ | (_| | | |  __/ | | | | (_) | | | |  __/
#   |_| |_| |_|\___|_|  \___|  \__,_|_|  \___| |_| |_|\___/|_| |_|\___|
#
#
#  _____ ___ ____ _     _____ _____ ____
# |  ___|_ _/ ___| |   | ____|_   _/ ___|
# | |_   | | |  _| |   |  _|   | | \___ \
# |  _|  | | |_| | |___| |___  | |  ___) |
# |_|   |___\____|_____|_____| |_| |____/

# %% [markdown]
# ## Exercise: Built-In Functions

# %%
def max_magnitude(*nums):
    return max(abs(num) for num in nums)

max_magnitude(50,300,-400)
# Out:
# 400

# %%
def sum_even_values(*nums):    
    """
    Add & return even values only
    """
    return sum(num for num in nums if num%2==0)

sum_even_values(5,1,2,9,4,8,3)
# Out:
# 14

# %%
def sum_floats(*args):
    """
    Add & return float values only
    """
    return sum(arg for arg in args if type(arg) == float)

sum_floats(1.5, 2.4, 'awesome', [], 1)
# Out:
# 3.9

# %% [markdown]
# ## Exercise: Errors
#
# Write a function called divide, which accepts two parameters (you can call them num1 and num2). The function should return the result of num1 divided by num2. If you do not pass the correct type of arguments to the function, it should return the string "Please provide two integers or floats". If you pass as the second argument a 0, Python will raise a ZeroDivisionError, so if this function is invoked with a 0 as the value of num2, return the string "Please do not divide by zero"

# %%
def divide(num1, num2):
    try:
        return num1 / num2
    except TypeError as err:
        return "Please provide two integers or floats"
    except ZeroDivisionError as err:
        return "Please do not divide by zero"

# %%
divide(1,2)
# Out:
# 0.5

# %%
divide(1,0)
# Out:
# 'Please do not divide by zero'

# %%
divide(1,"all")
# Out:
# 'Please provide two integers or floats'

# %% [markdown]
# ## Exercise: Functions

# %% [markdown]
# Return the day of the week passed as an integer 1-7

# %%
def return_day(day_num):
    days_of_week = ("Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday")
    if day_num < 1 or day_num > 7:
        return None
    else:
        return days_of_week[day_num-1]

return_day(3)
# Out:
# 'Tuesday'

# %% [markdown]
# Looking ahead to try/except, you could also write the above as…

# %%
def return_day(num):
    try:
        return ["Sunday","Monday", "Tuesday","Wednesday","Thursday","Friday","Saturday"][num-1]
    except IndexError as e:
        return None

# %% [markdown]
# Return last element of a list

# %%
def last_element(l):
    if l:
        return l[-1]
    return None

last_element([1,2,3,4])
# Out:
# 4

# %% [markdown]
# Return…
#
# * "First is greater" if the first param is greater than the second
# * "Second is greater" if the second is greater than the first
# * "Numbers are equal" if they're equal

# %%
def number_compare(a,b):
    if a > b:
        return "First is greater"
    elif b > a:
        return "Second is greater"
    return "Numbers are equal"

number_compare(7,10)
number_compare(4,2)
number_compare(5,5)
# Out:
# 'Numbers are equal'

# %% [markdown]
# Return how many times the 2nd param occurs in the first param.

# %%
def single_letter_count(s1, s2):
    return s1.lower().count(s2.lower())

single_letter_count("hello", "h")
# Out:
# 1

# %% [markdown]
# Return a dict of keys(letters in a string) in values(count of that letter in a string).

# %%
def multiple_letter_count(string):
    return {letter: string.count(letter) for letter in string}

multiple_letter_count('willow')
# Out:
# {'w': 2, 'i': 1, 'l': 2, 'o': 1}

# %%
def list_manipulation(thelist, cmd, loc, theval=None):
    if cmd == "remove":
        if loc == "beginning":
           return thelist.pop(0)
        return thelist.pop()
    elif cmd == "add":
        if loc == "beginning":
            thelist.insert(0, theval)
        else:
            thelist.append(theval)
        return thelist

list_manipulation([1,2,3], "remove", "end")
# Out:
# 3

# %%
list_manipulation([1,2,3], "remove", "beginning")
# Out:
# 1

# %%
list_manipulation([1,2,3], "add", "beginning", 20)
# Out:
# [20, 1, 2, 3]

# %%
list_manipulation([1,2,3], "add", "end", 30)
# Out:
# [1, 2, 3, 30]

# %%
def is_palindrome(word):
        # remove whitespace for good measure
    wordclean = word.replace(" ", "").lower()
    return wordclean == wordclean[::-1]

is_palindrome('Hannah')

is_palindrome('blake')
# Out:
# False

# %%
def frequency(thelist, search):
    return thelist.count(search)

frequency([1,2,3,4,3,31,2], 3)
# Out:
# 2

# %%
def multiply_even_numbers(lst):
    total = 1
    for val in lst:
        if val % 2 == 0:
            total = total * val
    return total

multiply_even_numbers([1,2,3,4,5,6])
# Out:
# 48

# %%
def capitalize(word):
    return word[0:1].upper() + word[1:].lower()

capitalize('aardvark')
# Out:
# 'Aardvark'

# %%
def compact(thelist):
    return [item for item in thelist if item]


compact([0,1,2,"",[],False,{},None,"All done"])
# Out:
# [1, 2, 'All done']

# %%
def intersection(list1, list2):
    return [item for item in list1 if item in list2]

intersection([1,2,3], [3,4,5])
# Out:
# [3]

# %% [markdown]
# ## Exercise: Generators

# %%
def week():
    weekdays = ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday')
    for day in weekdays:
        yield day

weekgen = week()
print(next(weekgen))
print(next(weekgen))
print(next(weekgen))
print(next(weekgen))
print(next(weekgen))
print(next(weekgen))
print(next(weekgen))
print(next(weekgen)) # <-- out of days
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-24-9c1dc5bc6f8a> in <module>
#      12 print(next(weekgen))
#      13 print(next(weekgen))
# ---> 14 print(next(weekgen)) # <-- out of days
#
# StopIteration:

# %%
def yes_or_no():
    answer = "yes"
    while True:
        yield answer
        answer = "no" if answer == "yes" else "yes"

yn = yes_or_no()
yn
print(next(yn))
print(next(yn))
print(next(yn))
print(next(yn))
# Out:
# yes
# no
# yes
# no

# %% [markdown]
# ## Exercise: MRO Genetics

# %%
class Mother:

    # dominant traits
    def __init__(self):
        self.eye_color = "brown"
        self.hair_color = "dark brown"
        self.hair_type = "curly"

class Father:

    # recessive traits
    def __init__(self):
        self.eye_color = "blue"
        self.hair_color = "blond"
        self.hair_type = "straight"

class Child(Mother, Father):
    
    def __init__(self):
        super().__init__()


billy = Child()

print(billy.eye_color)
print(billy.hair_color)
print(billy.hair_type)
# Out:
# brown
# dark brown
# curly

# %% [markdown]
# ## OOPS: Special Methods

# %%
class Train:

    def __init__(self, num_cars=0):
        self.num_cars = num_cars

    def __repr__(self):
        return "{} car train".format(self.num_cars)

    def __len__(self):
        return self.num_cars


a_train = Train(4)

# %%
a_train
# Out:
# 4 car train

# %%
len(a_train)
# Out:
# 4

# %% [markdown]
# ## Exercise: OOPS: RPG Classes

# %%
class Character:

    def __init__(self, name, hp=16, level=1):
        self.name = name
        self.hp = hp
        self.level = level


class NPC( Character ):

    def __init__(self, name, hp, level, speech):
        super().__init__(name, hp, level)
        self.speech = speech
    
    def speak(self):
        return f"{self.speech}"

# %%
alexan = Character('Alexan', 24, 1)
gnarioul = Character('Gnar\'ioul', 83, 5)
fellis = NPC('Fellis', 29, 3, 'I know not of these thieves, now please excuse me.')
marion = NPC('Marion', 8, 1, 'Mother told me to stay outside until dinner, so that\'s what I\'m doing!')

# %%
fellis.speak()
# Out:
# 'I know not of these thieves, now please excuse me.'

# %%
marion.speak()
# Out:
# "Mother told me to stay outside until dinner, so that's what I'm doing!"

# %% [markdown]
# ## Exercise: Screaming Repeating

# %%
how_many_times = input('How many times do I have to tell you? ')
how_many_times = int(how_many_times)

# not having 2 params in range means "0 to <var>" times
for time in range(how_many_times):
    print(f'Time {time+1}: Clean your room !'.upper())
# Out:
# TIME 1: CLEAN YOUR ROOM !
# TIME 2: CLEAN YOUR ROOM !
# TIME 3: CLEAN YOUR ROOM !

# %% [markdown]
# ## Exercise: Talking Animals

# %%
def speak(animal="dog"):
    sounds = {
        "pig": "oink",
        "duck": "quack",
        "cat": "meow",
        "dog": "woof"
    }
    sound = sounds.get(animal)
    if sound:
        return sound
    return "?"

# %%
speak()
# Out:
# 'woof'

# %%
speak("pig")
# Out:
# 'oink'

# %%
speak("berry")
# Out:
# '?'

# %% [markdown]
# ## Exercise 78: Bank Account

# %%
class BankAccount:

    def __init__(self, ownername):
        self.ownername = ownername
        self.balance = 0.0
    
    def show_balance(self):
        print(f"{self.ownername}'s balance is: $ {self.balance}")
    
    def deposit(self, amt):
        self.balance += amt
        self.show_balance()
    
    def withdraw(self, amt):
        self.balance -= amt
        self.show_balance()

# %%
acct = BankAccount("Rob")

acct

# %%
acct.show_balance()
# Out:
# Rob's balance is: $ 0.0

# %%
acct.deposit(1000)
# Out:
# Rob's balance is: $ 1000.0
